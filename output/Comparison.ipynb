# %% [markdown]
# # Replication Report — So sánh kết quả đã làm vs bài báo (BDCC-09-00069-v2)
#
# > Tài liệu này tổng hợp **những kết quả đã replicate được** và **chưa replicate được** khi so sánh với bài báo “Defining, Detecting, and Characterizing Power Users in Threads” (BDCC-09-00069-v2).
# > Tiêu chí replication có **2 mức độ**:
# >
# > 1) **Số liệu gần giống** (match định lượng)
# > 2) **Kết luận tương tự** (match định tính)
#
# ---
#
# ## 0) Nguồn & phạm vi đối chiếu
#
# ### 📌 Nguồn bài báo (BDCC-09-00069-v2)
# Các bảng được đối chiếu chủ yếu:
# - **Table 1**: Thống kê mạng tương tác tổng (T)
# - **Table 2**: % common nodes giữa top 20% của từng cặp centrality
# - **Table 3**: Mean/Median indegree của All users vs Power users
# - **Table 4**: Thống kê mạng con power users (P)
#
# ### 📌 Nguồn kết quả đã làm
# - Output thống kê mạng T/P (nodes, edges, density, clustering, diameter/ASP, assortativity…)
# - **table2_like_pairs.csv** (Table 2 tương tự)
# - **table3_like_indegree.csv** (Table 3 tương tự)
# - Tỷ lệ power users (top-20% giao của 4 centralities)
#
# ---
#
# ## 1) Mức 1 — “Số liệu gần giống”
#
# ### Những kết quả **replicate được** (gần giống / cùng cỡ bậc)
#
# #### 1.1 Mean indegree (All users) — khá sát
# - **Bài báo**: mean indegree (All) = **1.595**
# - **Tự làm**: mean indegree (All) = **1.639**
# ➡️ Lệch nhỏ, khá sát.
#
# #### 1.2 Avg indegree/outdegree của mạng T — cùng cỡ ~1.6
# - **Bài báo**: avg indegree/outdegree ≈ **1.595 / 1.595**
# - **Tự làm**: avg indegree/outdegree ≈ **1.613 / 1.613**
# ➡️ Cùng bậc độ lớn.
#
# #### 1.3 Tỷ lệ power users là “vài % rất nhỏ”
# - **Bài báo**: **2.59%** (1176 users)
# - **Tự làm**: **2.08%** (1127 users)
# ➡️ Cùng cỡ “nhỏ ~2–3%” (dù chưa khớp đúng con số).
#
# ---
#
# ### Những kết quả **chưa replicate được** (lệch rõ)
#
# #### 1.4 Table 2 — % common nodes giữa các top 20% (pattern bị đảo)
# **Bài báo** (K=20%):
# - D∩C: **10.31%**
# - D∩B: **7.79%**
# - D∩E: **7.05%**
# - C∩B: **4.44%**
# - C∩E: **3.78%**
# - B∩E: **18.76%** *(cao nhất)*
#
# **Tự làm** (table2_like_pairs.csv):
# - DnC: **4.274%**
# - DnB: **6.263%**
# - DnE: **4.082%**
# - CnB: **11.416%**
# - CnE: **13.803%** *(cao nhất)*
# - BnE: **8.906%**
#
# ➡️ Không chỉ lệch trị số, mà **cặp overlap cao nhất** cũng khác (bài báo: B∩E; tự làm: C∩E).
#
# ---
#
# #### 1.5 Table 3 — Mean/Median indegree (Power users lệch mạnh)
# **Bài báo**:
# - All users: mean **1.595**, median **1**
# - Power users: mean **19.076**, median **5**
#
# **Tự làm** (table3_like_indegree.csv):
# - All users: mean **1.639**, median **0**
# - Power users: mean **52.808**, median **0**
#
# ➡️ Điểm lệch quan trọng:
# - **Median indegree**: bài báo (1 và 5) vs tự làm (0 và 0) → lệch rất lớn
# - **Mean indegree power users**: tự làm cao hơn nhiều (52.8 vs 19.1)
#
# ---
#
# #### 1.6 Thống kê mạng T (Table 1) & mạng P (Table 4) — nhiều chỉ số không khớp
# Các khác biệt nổi bật tự làm đã thấy:
# - **Quy mô T** (nodes/edges) khác đáng kể so với bài báo
# - **Clustering (T)** đã làm cao hơn nhiều
# - **Connectivity**: bài báo báo cáo connectedness cao, tự làm có WCC lớn nhất < tổng nodes
# - **Path metrics** (diameter/avg shortest path) cũng khác
# - **Mạng P**: nodes/arcs/density/diameter/ASP/avg indegree… lệch so với Table 4
#
# ---
#
# ## 2) Mức 2 — “Kết luận tương tự”
#
# ### Những kết luận tự làm **replicate được** (tổng quan)
#
# #### 2.1 Power users là nhóm rất nhỏ
# ➡️ Tự làm cũng thu được tỷ lệ power users cỡ **~2%**, cùng kết luận “nhóm rất nhỏ”.
#
# #### 2.2 Mạng con power users (P) “đậm đặc hơn” mạng tổng (T)
# ➡️ Density và clustering của P cao hơn T (cùng hướng kết luận bài báo).
#
# ---
#
# ### Những kết luận tự làm **chưa replicate được** (chi tiết quan trọng)
#
# #### 2.3 Kết luận Table 3 về “median indegree của power users tăng rõ”
# - Bài báo nhấn mạnh median indegree tăng từ **1 → 5**
# - Tự làm ra median **0 → 0**
# ➡️ Vì vậy tự làm **chưa tái hiện được** thông điệp chính của Table 3.
#
# #### 2.4 Kết luận Table 2 về “mức chồng lấp giữa các centrality”
# - Pattern overlap đã làm **khác** bài báo
# ➡️ Chưa tái hiện được kết luận về quan hệ giữa các centrality (cặp nào chồng lấp mạnh/yếu).
#
# ---
#
# ## 3) Kết luận replication (theo 2 mức độ)
#
# ### Tự làm đang ở mức nào?
#
# - **Mức 1 (Số liệu gần giống):**  **Chưa đạt**
#   - Chỉ một số chỉ số “cỡ bậc” gần (vd: mean indegree all users).
#   - Các bảng trọng tâm **Table 2, Table 3**, và nhiều thống kê mạng **T/P** lệch rõ.
#
# - **Mức 2 (Kết luận tương tự):**  **Đạt (một phần, ở mức tổng quan)**
#   - Đúng hướng: power users rất ít; mạng P đậm hơn T.
#   - Nhưng chưa khớp các kết luận chi tiết gắn với Table 2 & Table 3.
#
# ➡️ Tóm gọn: **Tự làm đạt ~1/2 cấp độ** (đạt *kết luận tổng quan tương tự*, chưa đạt *số liệu gần giống*).
#
# ---
#
# ## 4) Checklist nhanh
#
# ### Tự làm đã replicate được
# - [x] Mean indegree (All users) gần bài báo
# - [x] Avg indegree/outdegree (T) cùng cỡ ~1.6
# - [x] Power users chiếm vài % rất nhỏ
# - [x] P có density/clustering cao hơn T (đúng hướng)
#
# ### Tự làm chưa replicate được
# - [ ] Table 2: pattern overlap giữa các centrality
# - [ ] Table 3: median indegree (All & Power) và mean indegree của Power
# - [ ] Nhiều chỉ số Table 1/4 (clustering/connectivity/path metrics) khớp sát bài báo
#
# ---
